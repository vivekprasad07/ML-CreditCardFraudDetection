# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to pandas data frame
`C:\\Users\\thevv\\OneDrive\\Desktop\\creditcard.csv")

# %%
#first five rows of the data set
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checking the number of misiing values in each column
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#cheking hte distribution of the legit and non legit transactions
data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#therefore this is very unbvalend as the percent of fraudulant transtion is very low so the prediction wilkl be faulty

#Highly unbalanced data set 
# 0 -> true transaction
#1 -> fraud

# %%
#sepearting the data for analysis
legit = data[data.Class == 0]
fraud = data[data.Class ==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statistical measure of this data

legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#comparing the values of fraud with legit
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#dealing with unbalanced data
#Under Sampling - build a sample data set from org data set containging similar distribution of the normna(legit) transaction and the fraud transaction

#Number of fraud transtion is 492
# we take 492 legit transtion and merge it with 492 flase transtion then it will be very good for machine learning

# %%
legit_sample = legit.sample(n=492)

# %%
#now concatinatin two dataframes

new_data = pd.concat([legit_sample,fraud], axis =0)#axis 0 means merge by rows

# %%
new_data.head()
# Out:
#            Time        V1        V2        V3        V4        V5        V6  \
# 28761   35146.0 -0.565924  1.158384  1.680954  0.024248 -0.165441 -1.069222
# 104688  69190.0 -0.320096  0.946312  1.391710  0.053293  0.065174 -0.865741
# 105830  69707.0 -1.086725  1.101925  1.476541  1.392101 -0.079487 -0.155354
# 81975   59186.0 -4.473728 -5.334814 -0.247607 -0.146372  2.318824 -2.865493
# 19516   30344.0  0.937989 -0.773762  1.125912  0.127427 -1.240490  0.231347
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 28761   0.752486 -0.166933 -0.463972  ... -0.182014 -0.470178  0.037427
# 104688  1.095034 -0.323093 -0.308008  ... -0.285553 -0.644304  0.050585
# 105830  0.484130  0.257961 -0.339709  ... -0.045611  0.276119 -0.017266
# 81975  -1.708967  0.660894 -1.229067  ...  0.288598 -0.789681  0.448050
# 19516  -0.796807  0.335031  0.918534  ...  0.021653  0.006536  0.030766
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95079.670732 -0.133260 -0.006929  0.184208 -0.133127 -0.010721
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.074736  0.026080 -0.023440  0.031915  ...  0.003691  0.027862
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.037999  0.003652  0.048306 -0.013502 -0.001899 -0.005671 -0.017331
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       90.171646
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Spliting the data into Featur and targets(0 or 1)

x = new_data.drop(columns='Class',axis=1)
y = new_data['Class']

# %%
print(x)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 28761    35146.0 -0.565924  1.158384  1.680954  0.024248 -0.165441 -1.069222
# 104688   69190.0 -0.320096  0.946312  1.391710  0.053293  0.065174 -0.865741
# 105830   69707.0 -1.086725  1.101925  1.476541  1.392101 -0.079487 -0.155354
# 81975    59186.0 -4.473728 -5.334814 -0.247607 -0.146372  2.318824 -2.865493
# 19516    30344.0  0.937989 -0.773762  1.125912  0.127427 -1.240490  0.231347
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(y)
# Out:
# 28761     0
# 104688    0
# 105830    0
# 81975     0
# 19516     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#Split the data into training data and testing data

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape, x_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
#Model training
#Using Logistic regression for binary Classification problem 0 1

model = LogisticRegression()

# %%
#training the Logistics regression Model with Training Data

model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#Model Evaluation based on accuracy scoree

#Accuracy Score
#accuracy on trainig data 
x_train_prediction = model.predict(x_train)
trainig_data_accuracy = accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy on trainign data : ', trainig_data_accuracy)
# Out:
# Accuracy on trainign data :  0.9326556543837357

# %%
#accuracy on test data 

x_test_prediction = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_prediction,y_test)

# %%
print('Accuract on testing Data : ',testing_data_accuracy)
# Out:
# Accuract on testing Data :  0.9289340101522843
